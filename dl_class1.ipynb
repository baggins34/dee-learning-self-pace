# %%
try:
    from google.colab import drive
    drive.mount('/content/drive', force_remount=True)
    COLAB = True
    print("Note: using Google CoLab")
    # %tensorflow_version 2.x
except:
    print("Note: not using Google CoLab")
    COLAB = False
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3aietf%3awg%3aoauth%3a2.0%3aoob&response_type=code&scope=email%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdocs.test%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive.photos.readonly%20https%3a%2f%2fwww.googleapis.com%2fauth%2fpeopleapi.readonly
#
# Enter your authorization code:
# ··········
# Mounted at /content/drive
# Note: using Google CoLab

# %%
# !ls /content/drive/My\ Drive/Colab\ Notebooks
# Out:
# dl_class1.ipynb

# %% [markdown]
# ## **Part 2**

# %%
a = 10 
print(f"The value of a is {a}")
# Out:
# The value of a is 10

# %% [markdown]
# without f the output: "The value of a is {a}"

# %%
# Another way is 
print("a is %d" % a)
# Out:
# a is 10

# %% [markdown]
# ### **Part 3**

# %%
l = ["a", "b", "c", "d"]
t = ("a", "b", "c", "d")

print(l)
print(t)
# Out:
# ['a', 'b', 'c', 'd']
# ('a', 'b', 'c', 'd')

# %%
# To change a value in a list
l[1] = "changed"
print(l)
# Out:
# ['a', 'changed', 'c', 'd']

# %%
for s in l:
  print(s)
# Out:
# a
# changed
# c
# d

# %%
for i, l in enumerate(l):
  print(f"{i}: {l}")
# Out:
# 0: a
# 1: changed
# 2: c
# 3: d

# %%
c = ['a', 'b', 'c']
print("First List: ", c)
c.insert(0, 'a0')
print("Second List: ", c)
c.remove('b')
print("Third List: ", c)
del c[0]
print("Forth List: ", c)
# Out:
# First List:  ['a', 'b', 'c']
# Second List:  ['a0', 'a', 'b', 'c']
# Third List:  ['a0', 'a', 'c']
# Forth List:  ['a', 'c']

# %%
s = set()
s = {'a', 'b', 'c'}
s = set(['a', 'b', 'c'])
print(s)
# Out:
# {'c', 'b', 'a'}

# %%
c = set()
c.add('a')
c.add('b')
c.add('c')
print(c)
# Out:
# {'c', 'b', 'a'}

# %%
d = {'Name': 'Frodo', 'Surname': 'Baggins'}
print("Dictionary", d)
print("Name in the dictionary: ", d['Name'])

if 'Name' in d:
  print("Name is defined.")

if 'Age' in d:
  print("Age is defined.")
else:
  print("Age is not defined.")

print(f"Keys of d: {d.keys()}, Values of d: {d.values()}")
# Out:
# Dictionary {'Name': 'Frodo', 'Surname': 'Baggins'}
# Name in the dictionary:  Frodo
# Name is defined.
# Age is not defined.
# Keys of d: dict_keys(['Name', 'Surname']), Values of d: dict_values(['Frodo', 'Baggins'])

# %%
customers = [{'Name': 'Lord Elrond', 'Pets': ["Asgolath", "Brigo", "Shadowfax"]},
             {'Name': 'Sauron', "Pets": ["Shelob", "Smaug"]},
             {'Name': "Elendil"}]

print(customers)

for customer in customers:
  print(f"{customer['Name']}: {customer.get('Pets', 'no pets')}")
# Out:
# [{'Name': 'Lord Elrond', 'Pets': ['Asgolath', 'Brigo', 'Shadowfax']}, {'Name': 'Sauron', 'Pets': ['Shelob', 'Smaug']}, {'Name': 'Elendil'}]
# Lord Elrond: ['Asgolath', 'Brigo', 'Shadowfax']
# Sauron: ['Shelob', 'Smaug']
# Elendil: no pets

# %%
a = [1, 2, 3, 4, 5]
b = [6, 7, 8, 9, 10]

print(zip(a, b))
# Out:
# <zip object at 0x7fa4d94e4f48>

# %%
print(list(zip(a, b)))
# Out:
# [(1, 6), (2, 7), (3, 8), (4, 9), (5, 10)]

# %%
for x, y in zip(a, b):
  print(f"{x} * {y} = {x*y}")
# Out:
# 1 * 6 = 6
# 2 * 7 = 14
# 3 * 8 = 24
# 4 * 9 = 36
# 5 * 10 = 50

# %%
a = [1, 2, 3, 4, 5, 6]
b = [7, 8, 9]
print(list(zip(a, b)))
# Out:
# [(1, 7), (2, 8), (3, 9)]

# %% [markdown]
# Use **enumerate** to track index location for a collection element

# %%
a = [34, 65, 89, 32, 56, 89, 0, 21, 65, 78, 99]
print("a at first: ", a)
for i, x in enumerate(a):
  if x > 33:
    a[i] = 5
print("a at last: ", a)
# Out:
# a at first:  [34, 65, 89, 32, 56, 89, 0, 21, 65, 78, 99]
# a at last:  [5, 5, 5, 32, 5, 5, 0, 21, 5, 5, 5]

# %%
my_list = [x**2 for x in range(10)]
print(my_list)
# Out:
# [0, 1, 4, 9, 16, 25, 36, 49, 64, 81]

# %%
text = ["col-one", "col-two", "col-three"]
look_up = {key: value for (value, key) in enumerate(text)}
print(look_up)
print(f"The value of col-two is: {look_up['col-two']}")
# Out:
# {'col-one': 0, 'col-two': 1, 'col-three': 2}
# The value of col-two is: 1

# %% [markdown]
# # **JSON**

# %%
jsonHardCoded = {
    "First-Name": "Frodo",
    "Last-Name": "Baggins",
    "is-Alive": True,
    "Age": 27,
    "Adress": {
        "Street-Adress": "Bag End",
        "Country": "Shire",
        "City": "Hobbiton"
    },
    "Phone-Number": [{"Type": "Home", "Number": "1234567"},
                     {"Type": "Work", "Number": "9876543"}],
    "Children": [],
    "Spouse": None
    }
print(jsonHardCoded)
# Out:
# {'First-Name': 'Frodo', 'Last-Name': 'Baggins', 'is-Alive': True, 'Age': 27, 'Adress': {'Street-Adress': 'Bag End', 'Country': 'Shire', 'City': 'Hobbiton'}, 'Phone-Number': [{'Type': 'Home', 'Number': '1234567'}, {'Type': 'Work', 'Number': '9876543'}], 'Children': [], 'Spouse': None}

# %%
import json

jsonHard = '{"First-Name": "Frodo", "Last-Name": "Baggins"}'
obj = json.loads(jsonHard)
print(f"First Name: {obj['First-Name']}")
# Out:
# First Name: Frodo

# %%
import requests

r = requests.get("https://raw.githubusercontent.com/jeffheaton/"
                 +"t81_558_deep_learning/master/person.json")
print(r.json())
# Out:
# {'firstName': 'John', 'lastName': 'Smith', 'isAlive': True, 'age': 27, 'address': {'streetAddress': '21 2nd Street', 'city': 'New York', 'state': 'NY', 'postalCode': '10021-3100'}, 'phoneNumbers': [{'type': 'home', 'number': '212 555-1234'}, {'type': 'office', 'number': '646 555-4567'}, {'type': 'mobile', 'number': '123 456-7890'}], 'children': [], 'spouse': None}

# %%
python_obj = {"Firs-Name": "Frodo", "Last-Name": "Baggins"}
print(json.dumps(python_obj))
# Out:
# {"Firs-Name": "Frodo", "Last-Name": "Baggins"}

# %% [markdown]
# ## **Part 4**

# %%
import pandas as pd 

df = pd.read_csv("https://data.heatonresearch.com/data/t81-558/iris.csv")
#display(df.head())
display(df[:5])
# Out:
#    sepal_l  sepal_w  petal_l  petal_w      species
# 0      5.1      3.5      1.4      0.2  Iris-setosa
# 1      4.9      3.0      1.4      0.2  Iris-setosa
# 2      4.7      3.2      1.3      0.2  Iris-setosa
# 3      4.6      3.1      1.5      0.2  Iris-setosa
# 4      5.0      3.6      1.4      0.2  Iris-setosa

# %% [markdown]
# **What if we want to "stream" a huge file.**

# %%
import csv
import urllib.request
import codecs
import numpy as np

url = "https://data.heatonresearch.com/data/t81-558/iris.csv"

urlstream = urllib.request.urlopen(url)
csvfile = csv.reader(codecs.iterdecode(urlstream, "utf-8"))
next(csvfile)  # Skip header row

sum = np.zeros(4)
count = 0

for line in csvfile:
  line2 = np.array(line)[:4].astype(float)

  if len(line2) == 4:
    sum += line2
    count += 1

print(sum/count)
# Out:
# [5.84333333 3.05733333 3.758      1.19933333]

# %% [markdown]
# **Read a text File**

# %%
import urllib.request

url = "https://www.constitution.org/usdeclar.txt"
with urllib.request.urlopen(url) as urlstream:
    for line in codecs.iterdecode(urlstream, 'utf-8'):
        print(line.rstrip())

# %% [markdown]
# **Read an Image**

# %%
# %matplotlib inline
from PIL import Image
import requests
from io import BytesIO

url = "https://upload.wikimedia.org/wikipedia/commons/9/92/Brookings.jpg"

response = requests.get(url)
img = Image.open(BytesIO(response.content))

img
# Out:
# Output hidden; open in https://colab.research.google.com to view.

# %% [markdown]
# ## **Part 5**

# %%
def say_hello(speaker, person_to_greet, greeting="Hello"):
  print(f"{greeting} {person_to_greet}, this is {speaker}")

say_hello("Elrond", "Gandalf")
say_hello("Galadriel", "Mithrandir", "Mellon")
# Out:
# Hello Gandalf, this is Elrond
# Mellon Mithrandir, this is Galadriel

# %%
def process_string(str):
  t = str.strip()
  return t[0].upper() + t[1:]

process_string("theoden           ")
# Out:
# 'Theoden'

# %%
the_list = ["       elrond       ",  "              arwen         ", "         gimli            ", "        thranduil            "]
last_list = list(map(process_string, the_list))
print(last_list)
# Out:
# ['Elrond', 'Arwen', 'Gimli', 'Thranduil']

# %%
second_list = ["      moria   ", "    shire", "        mordor         ", "     imladris         "]
final_list = [ i for i in map(process_string, second_list)]
print(final_list)
# Out:
# ['Moria', 'Shire', 'Mordor', 'Imladris']

# %%
def greater_than_five(x):
  return x > 5

my_list = [1, 2, 3, 4, 5, 6, 7, 8, 9]

filtered_list = [i for i in filter(greater_than_five, my_list)]
print(filtered_list)
# Out:
# [6, 7, 8, 9]

# %%
lambda_list = list(filter(lambda x: x > 6, my_list))
print(lambda_list)
# Out:
# [7, 8, 9]

# %%
from functools import reduce

result = (reduce(lambda x, y: x+y, my_list))
print(result)
# Out:
# 45
